# %% [markdown]
# # **Python OOPs Questions**
#
# #question-1.What is Object-Oriented Programming (OOP)?
# - Object-Oriented Programming (OOP) is a way to write code by using "objects." An object is like a thing that has attributes (like color or size) and actions (things it can do).
#
# #question-2.What is a class in OOP?
# - In Object-Oriented Programming (OOP), a class is like a blueprint or template for creating objects.
#
# #question-3.What is an object in OOP?
# - In Object-Oriented Programming (OOP), an object is a thing created from a class. It is a real, usable version of the blueprint (class) that holds actual data and can perform actions.
#
# #question-4.What is the difference between abstraction and encapsulation?
# - Abstraction
#   - Hides the details and shows only the important stuff.
#
# - Encapsulation
#   - Hides the data and protects it from being changed directly.
#
# #question-5.What are dunder methods in Python?
# - Dunder methods in Python (short for "double underscore" methods) are special built-in methods that start and end with double underscores, like __init__, __str__, __len__, etc.
#
# - They are also called magic methods because Python automatically calls them for certain operations.
#
# #question-6.Explain the concept of inheritance in OOP.
# - Inheritance means one class gets properties and methods from another class. It's like a child inheriting features from a parent.
#
# #question-7.What is polymorphism in OOP?
# - Polymorphism means "many forms". It lets you use the same method name for different objects, and the method can do different things depending on the object.
#
# #question-8. How is encapsulation achieved in Python?
# - Encapsulation in Python is about protecting the data (attributes) of a class and restricting access to it directly. Instead, you control how data is accessed or modified through methods (functions).
#   - it is achived by 2 methods:-
#     - private method -You make variables private by prefixing them with __ (double underscore), making it harder to access them directly from outside the class.
#     - Public Methods- You create getter and setter methods to safely access and modify the private data.
#
# #question-9.What is a constructor in Python?
# - A constructor in Python is a special method that is automatically called when an object of a class is created. It is used to initialize the object's attributes (data) when the object is created.
#
# #question-10.What are class and static methods in Python?
# - Class Method (@classmethod): A method that takes cls (the class) as its first parameter. It can modify class-level attributes.
#
# - Static Method (@staticmethod): A method that doesn't take self or cls as its first parameter. It doesn’t modify instance or class attributes and is just a utility function related to the class.
#
# #question-11. What is method overloading in Python?
# - In Python, if you define multiple methods with the same name, the last one defined will overwrite the previous ones.
#
# ```python
# class babu bhaiya :
#     def raju (self, name):
#         print(f"Hello, {name}")
#
#     # This method would overwrite the first one
#     def raju (self, name, age):
#         print(f"Hello, {name}, you are {age} years old.")
#
# ```
#
# #question-12. What is method overriding in OOP?
# - oop overidiing occurs when a new subclass has same function or name which is already mentioned in its parent class which allows python to overide the orginal function with the new function.
#
# #question-13.What is a property decorator in Python?
# - The @property decorator is used to control access to class attributes — like adding logic when you get, set, or delete a value, but still using it like a normal variable.
#
# #question-14.Why is polymorphism important in OOP?
#
#   1. Polymorphism allows objects of different classes to respond to the same method in their own way.
#
#   2. It enables code reusability by using a single interface to handle multiple types of objects.
#
#   3. It supports method overriding and allows subclasses to define their own behavior for inherited methods.
#
#   4. Polymorphism improves flexibility and maintainability by making it easy to add new classes without modifying existing code.
#
# #question-15.What is an abstract class in Python?
# - it is like You can't access it directly, but it tells you what you need to access it through a child class.
#
# #question-16.What are the advantages of OOP?
# - advantages of oop:-
#  - 1. we can re use the same the code multiple times.
#  - 2. it makes your code for short and clean.
#  - 3. it keeps your inofrmation safe.
#  - 4. in this we can use same name for different functions.
#  - 5. it is easy to update.
#
# #question-17.What is the difference between a class variable and an instance variable?
# -
# 1. **Class variable** is shared by all objects.
# 2. **Instance variable** is unique to each object.
# 3. **Class variable** is defined outside methods.
# 4. **Instance variable** is defined using `self` inside methods.
# 5. Changing a **class variable** affects all instances.
# 6. Changing an **instance variable** affects only that object.
#
# #question-18. What is multiple inheritance in Python?
# - multiple inheritance in python means an child class can inheritate from more then one parent class.
#
# example-
# ```python
# class papa :
#   def love(self):
#     print("i love you")
#
# class mummy :
#   def love(self):
#     print("i love you")
#
# class beta(papa,mummy):
#   def lele(self)
#    print("mai beta hu")
#
#    ```
# #question-19.Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
# - __str__: For humans. It's meant to give a nice, readable description of the object. When you use print(), Python uses __str__.
#
# - __repr__: For developers. It should give a technical, detailed string that could help to recreate the object or give extra info about it. It's what Python uses when you type an object in the interpreter or use repr().
#
# #question-20.What is the significance of the ‘super()’ function in Python?
# - The super() function in Python is a way to call methods or access properties from a parent class (the class your class is inheriting from) in your child class.
#
# #question-21.What is the significance of the __del__ method in Python?
# - The purpose of __del__ is to allow an object to clean up any resources that has been holding onto before it is deleted by garbage cleaner.
#
# #question-22.What is the difference between @staticmethod and @classmethod in Python?
# - A @staticmethod is a method that doesn’t need access to the instance (self) or the class (cls). It behaves like a regular function that is bound to the class, but it doesn’t have access to instance-specific or class-specific data.
#
# - A @classmethod is a method that takes the class itself (cls) as the first argument, not the instance. This allows the method to modify class-level properties or to access class-level methods. It is bound to the class rather than an instance.
#
# #question-23.How does polymorphism work in Python with inheritance?
# - Polymorphism allows different classes to have the same method name, but each class can implement the method differently. This means you can call the same method on objects of different classes, and each class will respond in its own way.
#
# - How It Works with Inheritance:
# it ensures that when we call the child classes it gives the correct child class out of all child class with same name.
#
# example
#
# ```python
#
# class animal:
#   def speak (self):
#     print("baba bangali")
#
# class dog(animal):
#   def speak (self):
#     print("baba bangali tu")
#
# class cat(animal):
#   def speak (self):
#     print("baba tu bangali")
#
# animals = [Dog(), Cat()]
#
# for animal in animals:
#     animal.speak()
# ```
#
# #question-24.What is method chaining in Python OOP?
# - Method chaining is a technique in object-oriented programming where multiple methods are called on the same object, one after the other, in a single line of code.
#
# #question-25.What is the purpose of the __call__ method in Python?
# - the __call__ method in Python is a special method that allows an instance of a class to be called like a function. This means that you can use an object of a class as if it were a function, and it will trigger the __call__ method.
#
# ```python
# class baba:
#     def __call__(self, name):
#         return f"Hello, {name}!"
# greeter = baba()
# result = greeter("John")
# print(result)
# ```

# %% [markdown]
# # Practical Questions
# #question-1.Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

# %%
class animal:
  def speak(self):
    print("baba bangali")

class dog(animal):
  def speak(self):
    print("bark!")

dog1=dog()
dog1.speak()
# Out:
# bark!

# %% [markdown]
# #question-2.Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

# %%
#Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.
import math
from abc import ABC, abstractmethod
class Shape(ABC):

    @abstractmethod
    def area(self):
        pass
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return math.pi * self.radius ** 2
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width
circle = Circle(10)
rectangle = Rectangle(1, 2)

print("Area of Circle:", circle.area())
print("Area of Rectangle:", rectangle.area())
# Out:
# Area of Circle: 314.1592653589793
# Area of Rectangle: 2

# %% [markdown]
# Question-3.Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery):
        super().__init__(vehicle_type, brand)
        self.battery = battery
ecar = ElectricCar("Electric", "Tesla", "75 kWh")

print("Type:", ecar.type)
print("Brand:", ecar.brand)
print("Battery:", ecar.battery)
# Out:
# Type: Electric
# Brand: Tesla
# Battery: 75 kWh

# %% [markdown]
# Question-4.Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

# %%
class Bird:
    def fly(self):
        print("Some birds can fly.")
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky.")
class Penguin(Bird):
    def fly(self):
        print("Penguins can't fly, they swim.")


def show_flight(bird):
    bird.fly()

bird1 = Sparrow()
bird2 = Penguin()


show_flight(bird1)
show_flight(bird2)
# Out:
# Sparrow flies high in the sky.
# Penguins can't fly, they swim.

# %% [markdown]
# Question-5.Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
    def __init__(self):
        self.__balance = 0  # Private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: {amount}")
        else:
            print("Insufficient balance or invalid amount.")

    def check_balance(self):
        print(f"Current Balance: {self.__balance}")

account = BankAccount()
account.deposit(1000)
account.withdraw(500)
account.check_balance()
# Out:
# Deposited: 1000
# Withdrawn: 500
# Current Balance: 500

# %% [markdown]
# Question-6.Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play()

# %%
class Instrument:
    def play(self):
        print("Instrument is playing.")

class Guitar(Instrument):
    def play(self):
        print("Guitar is strumming.")

class Piano(Instrument):
    def play(self):
        print("Piano is playing melody.")

def start_playing(instrument):
    instrument.play()

guitar = Guitar()
piano = Piano()


start_playing(guitar)
start_playing(piano)
# Out:
# Guitar is strumming.
# Piano is playing melody.

# %% [markdown]
# Question-7.Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

sum_result = MathOperations.add_numbers(10, 5)
diff_result = MathOperations.subtract_numbers(10, 5)

print("Sum:", sum_result)
print("Difference:", diff_result)
# Out:
# Sum: 15
# Difference: 5

# %% [markdown]
# Question-8.Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    count = 0  # Class variable to track number of persons

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

p1 = Person("ena")
p2 = Person("mina")
p3 = Person("dika")

print("Total persons created:", Person.total_persons())
# Out:
# Total persons created: 3

# %% [markdown]
# Question-9.Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Example usage
f1 = Fraction(3, 4)
f2 = Fraction(5, 8)

print(f1)
print(f2)
# Out:
# 3/4
# 5/8

# %% [markdown]
# Question-10.Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y


    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)


    def __str__(self):
        return f"({self.x}, {self.y})"

v1 = Vector(1, 3)
v2 = Vector(2, 4)
v3 = v1 + v2

print("v1:", v1)
print("v2:", v2)
print("v1 + v2:", v3)
# Out:
# v1: (1, 3)
# v2: (2, 4)
# v1 + v2: (3, 7)

# %% [markdown]
# Question-11.Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

person1 = Person("gafur ghisela", 20)
person1.greet()
# Out:
# Hello, my name is gafur ghisela and I am 20 years old.

# %% [markdown]
# Question-12.Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name  # Attribute for the student's name
        self.grades = grades  # Attribute for the list of grades

    def average_grade(self):
        if len(self.grades) == 0:
            return 0  # Avoid division by zero if there are no grades
        return sum(self.grades) / len(self.grades)  # Compute average of grades

student1 = Student("jethalal gada ", [85, 90, 78, 92])
print(f"{student1.name}'s average grade: {student1.average_grade()}")
# Out:
# jethalal gada 's average grade: 86.25

# %% [markdown]
# Question-13.Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.

# %%
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

rectangle = Rectangle()
rectangle.set_dimensions(5, 3)
print(f"Area of the rectangle: {rectangle.area()}")
# Out:
# Area of the rectangle: 15

# %% [markdown]
# Question-14.Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        # Initialize the base class (Employee) using super()
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        # Calculate base salary and add bonus
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

employee = Employee("John", 40, 25)
print(f"{employee.name}'s salary: ${employee.calculate_salary()}")

manager = Manager("Alice", 40, 30, 500)
print(f"{manager.name}'s salary: ${manager.calculate_salary()}")
# Out:
# John's salary: $1000
# Alice's salary: $1700

# %% [markdown]
# Question-15.Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name  # Attribute for product name
        self.price = price  # Attribute for product price
        self.quantity = quantity  # Attribute for product quantity

    def total_price(self):
        return self.price * self.quantity  # Calculate total price

product1 = Product("Laptop", 1000, 2)
product2 = Product("Headphones", 50, 5)

print(f"Total price of {product1.name}: ${product1.total_price()}")
print(f"Total price of {product2.name}: ${product2.total_price()}")
# Out:
# Total price of Laptop: $2000
# Total price of Headphones: $250

# %% [markdown]
# Question-16.Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

# %%
from abc import ABC, abstractmethod


class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass  # Abstract method that must be implemented by subclasses


class Cow(Animal):
    def sound(self):
        print("Moo")


class Sheep(Animal):
    def sound(self):
        print("Baa")

cow = Cow()
sheep = Sheep()

cow.sound()
sheep.sound()
# Out:
# Moo
# Baa

# %% [markdown]
# Question-17.Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title  # Attribute for book title
        self.author = author  # Attribute for book author
        self.year_published = year_published  # Attribute for year of publication

    def get_book_info(self):
        # Returns a formatted string with book's details
        return f"'{self.title}' by {self.author}, published in {self.year_published}"


book1 = Book("geeta", "shri krishna", 1990)
book2 = Book("kavita", "bablu", 2023)

print(book1.get_book_info())
print(book2.get_book_info())
# Out:
# 'geeta' by shri krishna, published in 1990
# 'kavita' by bablu, published in 2023

# %% [markdown]
# Question-18.Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def get_info(self):
        return f"Address: {self.address}, Price: ${self.price}"

# Derived class
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def get_info(self):
        base_info = super().get_info()
        return f"{base_info}, Number of Rooms: {self.number_of_rooms}"

house = House("123 Main St, Springfield", 250000)
mansion = Mansion("456 Lux Ave, Beverly Hills", 5000000, 10)

print(house.get_info())
print(mansion.get_info())
# Out:
# Address: 123 Main St, Springfield, Price: $250000
# Address: 456 Lux Ave, Beverly Hills, Price: $5000000, Number of Rooms: 10
